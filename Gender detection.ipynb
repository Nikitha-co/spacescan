# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import chardet
with open('/content/Gender_Detection.csv.zip','rb') as f:
  result = chardet.detect(f.read())
  print(result['encoding'])
# Out:
# None

# %%
data = pd.read_csv('/content/Gender_Detection.csv.zip', encoding = 'unicode_escape')
data
# Out:
#            Name Gender
# 0         James      M
# 1          John      M
# 2        Robert      M
# 3       Michael      M
# 4       William      M
# ...         ...    ...
# 147264   Zylenn      M
# 147265   Zymeon      M
# 147266   Zyndel      M
# 147267   Zyshan      M
# 147268    Zyton      M
#
# [147269 rows x 2 columns]

# %%
data.isna().sum()
# Out:
# Name      0
# Gender    0
# dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# F    89749
# M    57520
# Name: Gender, dtype: int64

# %%
data['Gender'] = data['Gender'].replace({'M' : 1, 'F' : 0})

encoder = preprocessing.LabelEncoder()
encoder.fit(data['Name'])
data['Name'] = pd.DataFrame(encoder.transform(data['Name']))

# %%
data
# Out:
#           Name  Gender
# 0        52308       1
# 1        57879       1
# 2       102035       1
# 3        84621       1
# 4       128418       1
# ...        ...     ...
# 147264  133797       1
# 147265  133823       1
# 147266  133843       1
# 147267  133892       1
# 147268  133902       1
#
# [147269 rows x 2 columns]

# %%
X = data.drop('Gender', axis = 1)
Y= data['Gender']

# %%
X
# Out:
#           Name
# 0        52308
# 1        57879
# 2       102035
# 3        84621
# 4       128418
# ...        ...
# 147264  133797
# 147265  133823
# 147266  133843
# 147267  133892
# 147268  133902
#
# [147269 rows x 1 columns]

# %%
Y
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 147264    1
# 147265    1
# 147266    1
# 147267    1
# 147268    1
# Name: Gender, Length: 147269, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.8, random_state = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e4109da2b949> in <cell line: 1>()
# ----> 1 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.8, random_state = 1)
#
# NameError: name 'train_test_split' is not defined

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (147269, 1) (117815, 1) (29454, 1)

# %%
models = {
    'Logistic Regression' : LogisticRegression(),
    'Decision Tree' : DecisionTreeClassifier(),
    'Random Forest' : RandomForestClassifier(),
    'Neural Network' : MLPClassifier(),
    'Ada Boost' : AdaBoostClassifier()
}

for name, model in models.items():
    model.fit(X_train, Y_train)
    print(name + ' trained!')
# Out:
# Logistic Regression trained!
# Decision Tree trained!
# Random Forest trained!
# Neural Network trained!
# Ada Boost trained!

# %%
for name, model in models.items():
    score = model.score(X_test, Y_test)
    print(name + ' Accuracy is: {:.2f}%'.format(score * 100))
# Out:
# Logistic Regression Accuracy is: 61.04%
# Decision Tree Accuracy is: 56.70%
# Random Forest Accuracy is: 56.61%
# Neural Network Accuracy is: 38.96%
# Ada Boost Accuracy is: 61.10%
